# %% [markdown]
# In this notebook we are trying to build a model to predict whether a mushroom is poisonous or safe to eat. This label is represented by the category 'class'. 'e' stands for edible and 'p' for poisonous. We will examine a series of different machine learning algorithms and employ cross validation in order to find the model or algorithm with the most predictive power.

# %%
import os
import pandas as pd
import numpy as np
from sklearn import preprocessing, cross_validation
import matplotlib.pyplot as plt
from matplotlib import style
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
style.use('fivethirtyeight')

# %%
os.chdir('C:\\Users\\GordonMango2413\\Desktop\\mushrooms')

# %% [markdown]
# Class is the variable we are trying to predict. In machine learning speak, class would be our label and the other variables would be our features. Or in other words class is a class and we are trying to create a model to determine the common attributes of each class.

# %%
fungi=pd.read_csv('mushrooms.csv')

fungi.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# count          8124      8124       8124   ...                       8124
# unique            2         2         12   ...                          4
# top               c         b          b   ...                          s
# freq           6812      5612       1728   ...                       4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# ...

# %%
fungi.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
# Out:
#   File "<ipython-input-80-c222ff78aaab>", line 1
#     fungi.class()
#               ^
# SyntaxError: invalid syntax

# %%
df=pd.get_dummies(fungi, drop_first=True)
#We are getting dummy variables for each feature, and we are droppng the first class for each variable because only n-1 dummies
#are needed to encode n classes

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2569c44faf66> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# We are trying to predict class, so in order to set up out model we have to separate it into its in variable. We are also removing veil-type from the data because all muushrooms have the same veil type. Therefore, veil type has no predictive value. In addition, all of our data is categorical and currently defined by strings. In order to run a model on the data we have to transform it into numerical data. Here we are using the label encoder function to create numerical classes for each variable.

# %%
plt.scatter(df['cap-shape'],label )
plt.show()
